# %%
import pandas as pd
import json

# %% [markdown]
# # 1. Load Raw Data

# %%
with open("../data/cost_of_living_raw.json", "r", encoding="utf-8") as f:
    raw_data = json.load(f)

df_raw = pd.DataFrame(raw_data)

# %% [markdown]
# # 2. Select and Rename Relevant Fields

# %%
columns_to_keep = {
    "Average Monthly Net Salary (After Tax)": "net_salary",
    "Apartment (1 bedroom) in City Centre": "apt1_city_centre",
    "Meal, Inexpensive Restaurant": "meal_cheap",
    "Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)": "internet",
    "Basic (Electricity, Heating, Cooling, Water, Garbage) for 915 sq ft Apartment": "utilities",
    "Cappuccino (regular)": "coffee",
    "Gasoline (1 gallon)": "gasoline",
    "Domestic Beer (0.5 liter bottle)": "beer",
    "One-way Ticket (Local Transport)": "ticket_oneway",
    "Monthly Pass (Regular Price)": "ticket_monthly"
}

base_cols = ["City Name", "country"]
df_reduced = df_raw[base_cols + list(columns_to_keep.keys())].copy()
df_reduced = df_reduced.rename(columns=columns_to_keep)

# %% [markdown]
# # 3. Convert All Values to Euro

# %%
def convert_to_eur(value):
    if not isinstance(value, str):
        return None
    value = value.replace(",", "").strip()

    if value.endswith("€"):
        return float(value.replace("€", "").strip())
    elif value.endswith("$"):
        return float(value.replace("$", "").strip()) / 1.15
    elif value.endswith("Fr."):
        return float(value.replace("Fr.", "").strip()) / 0.94
    else:
        return None

for col in columns_to_keep.values():
    df_reduced[col] = df_reduced[col].apply(convert_to_eur)

# %%
df_reduced = df_reduced.rename(columns={"City Name": "city"})

# %% [markdown]
# # 4. Fill Missing Values

# %% [markdown]
# ### Fill in missing values using the average per country for each column.

# %%
for col in df_reduced.columns:
    if col not in ["city", "country"]:
        df_reduced[col] = df_reduced.groupby("country")[col].transform(lambda x: x.fillna(x.mean()))

# %% [markdown]
# # 5. Round all fields to two decimal places

# %%
numeric_cols = df_reduced.select_dtypes(include="number").columns
df_reduced[numeric_cols] = df_reduced[numeric_cols].round(2)

# %% [markdown]
# # Rename City Names

# %%
city_map = {
    'vienna':      'Wien',
    'graz':        'Graz',
    'linz':        'Linz',
    'salzburg':    'Salzburg',
    'Berlin':      'Berlin',
    'munich':      'München',
    'hamburg':     'Hamburg',
    'dusseldorf':  'Düsseldorf',
    'frankfurt':   'Frankfurt',
    'hannover':    'Hannover',
    'nuremberg':   'Nürnberg',
    'essen':       'Essen',
    'cologne':     'Köln',
    'bern':        'Bern',
    'zurich':      'Zürich',
    'geneva':      'Genf',
    'basel':       'Basel'
}

df_reduced['city'] = df_reduced['city'].str.lower()
df_reduced['city'] = df_reduced['city'].replace(city_map)
df_reduced['city'] = df_reduced['city'].str.title()

# %% [markdown]
# # 6. Output

# %%
df_reduced
# Out:
#           city      country  net_salary  apt1_city_centre  meal_cheap  \
# 0         Wien      austria     2641.54           1032.14       15.00
# 1         Graz      austria     2551.07            700.00       14.00
# 2         Linz      austria     2229.89            615.44       18.00
# 3     Salzburg      austria     2763.55           1106.25       15.00
# 4       Berlin      germany     2891.64           1229.35       15.00
# 5      München      germany     3382.65           1523.38       18.00
# 6      Hamburg      germany     2540.87           1043.48        8.70
# 7   Düsseldorf      germany     3060.21           1070.00       15.00
# 8    Frankfurt      germany     3666.67            685.00        7.00
# 9     Hannover      germany     2434.78           1063.16       16.52
# 10    Nürnberg      germany     3186.06            838.00       15.00
# 11       Essen      germany     2434.78           1063.16       16.52
# 12        Köln      germany     2628.25           1052.94       14.00
# 13        Bern  switzerland     6186.36           1623.53       24.23
# 14      Zürich  switzerland     6749.86           2384.76       26.60
# 15        Genf  switzerland     3304.35           1304.35       18.26
# 16       Basel  switzerland     6948.82           1812.65       26.60
#
#     internet  utilities  coffee  gasoline  beer  ticket_oneway  ticket_monthly
# 0      36.00     285.15    4.22      6.10  1.29           2.40           40.00
# 1      31.34     323.19    3.80      5.83  1.33           3.00           62.75
# 2      34.67     300.42    3.80      5.70  1.34           2.70           54.45
# 3      37.33     330.32    4.12      5.72  1.29           2.40           75.00
# 4      40.59     313.46    3.77      6.54  1.01           3.50           58.00
# 5      40.13     349.58    3.79      6.54  1.02           4.00           58.00
# 6     130.43      79.17    4.35      2.61  2.49           1.74           86.96
# 7      42.05     305.82    3.59      6.57  0.90           3.40           56.50
# 8      45.42     284.00    1.00      6.52  0.89           1.95           53.50
# 9      62.80     403.26    3.12      3.16  2.18           3.05           61.28
# 10     43.37     297.76    3.80      6.57  0.92           3.49           58.00
# 11     62.80     403.26    3.12      3.16  2.18           3.05           61.28
# 12     43.64     344.34    3.77      6.45  0.94           3.30           58.00
# 13     50.00     321.21    4.99      7.17  1.66           3.19           84.57
# 14     50.96     218.77    5.84      7.46  2.34           4.26           92.55
# 15     43.48     160.52    4.93      2.70  2.10           3.83           89.54
# 16     51.39     262.07    5.77      7.12  2.07           4.04           91.49

# %% [markdown]
# # 7. Save as CSV

# %%
output_path = "../output/cost_of_living_cleaned.csv"
df_reduced.to_csv(output_path, index=False, encoding="utf-8")
print(f"CSV-Datei gespeichert unter: {output_path}")
# Out:
# CSV-Datei gespeichert unter: ../output/cost_of_living_cleaned.csv
